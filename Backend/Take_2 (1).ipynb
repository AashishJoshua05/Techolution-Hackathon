# %%
pip install librosa scikit-learn python_speech_features sounddevice tqdm

# %%
import os
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from python_speech_features import mfcc
from tqdm import tqdm

# %%
import librosa
import numpy as np

# Function to extract MFCC features
def extract_mfcc_features(audio, sr=16000, num_cepstral=13, frame_length=0.02, frame_stride=0.02,
                           num_filters=32, fft_length=320, preemphasis_coeff=0.98):
    # Apply pre-emphasis
    audio = np.append(audio[0], audio[1:] - preemphasis_coeff * audio[:-1])

    # Compute the short-time Fourier transform (STFT)
    hop_length = int(frame_stride * sr)
    n_fft = fft_length
    window = "hann"  # You can choose a different window function if needed
    stft_result = librosa.core.stft(audio, hop_length=hop_length, n_fft=n_fft, window=window)

    # Compute the mel spectrogram
    mel_spectrogram = librosa.feature.melspectrogram(S=np.abs(stft_result)**2, sr=sr, n_mels=num_filters)

    # Logarithm of the mel spectrogram
    log_mel_energy = np.log(mel_spectrogram + 1e-9)

    # Extract MFCC features using DCT
    mfcc_features = librosa.feature.mfcc(S=log_mel_energy, n_mfcc=num_cepstral)

    # Apply mean and variance normalization across time
    mfcc_features = librosa.util.normalize(mfcc_features, norm=2, axis=0, fill=True)

    return mfcc_features

# %%
def preprocess_data(data_dir):
    data = []
    labels = []
    features = []

    for class_label in os.listdir(data_dir):
        class_path = os.path.join(data_dir, class_label)
        for file_name in tqdm(os.listdir(class_path), desc=f"Processing {class_label}"):
            file_path = os.path.join(class_path, file_name)
            audio, _ = librosa.load(file_path, sr = 16000)

            # Simply append the raw audio data to the dataset
            data.append({
                'audio': audio,
                'label': class_label
            })
            mfcc_features = extract_mfcc_features(audio)
            features.append(mfcc_features)
            labels.append(class_label)

    features = np.array(features)
    labels = np.array(labels)
    classes = set(labels)

     #Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

    return features ,classes ,(X_train, y_train), (X_test, y_test)
# Example usage
data_dir = "/content/drive/MyDrive/hackathon"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.optimizers import Adam

def train_model(X_train, y_train, num_classes, X_test, y_test):
    encoder = LabelEncoder()
    encoded_labels_train = encoder.fit_transform(y_train)
    encoded_labels_test = encoder.transform(y_test)

    model = models.Sequential([
        layers.Input(shape=(X_train.shape[1], X_train.shape[2])),
        layers.Reshape((X_train.shape[1], X_train.shape[2], 1)),
        layers.Conv2D(8, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(0.25),
        layers.Conv2D(16, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer=Adam(learning_rate=0.01), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()

    model.fit(X_train, encoded_labels_train, epochs=100, batch_size=32, validation_data=(X_test, encoded_labels_test))

    model.save("custom_model.keras")

    return model, encoder

# Assuming you have features, classes, (X_train, y_train), (X_test, y_test) from preprocess_data
features, classes, (X_train, y_train), (X_test, y_test) = preprocess_data(data_dir)
num_classes = len(classes)

# Print shapes of MFCC features and model input
print("MFCC Features Shape:", features.shape)
print("Model Input Shape:", X_train.shape[1:])

# Train the model
trained_model, label_encoder = train_model(X_train, y_train, num_classes, X_test, y_test)
# Out:
# Processing door_close: 100%|██████████| 3503/3503 [00:30<00:00, 113.48it/s]
# Processing door_open: 100%|██████████| 6398/6398 [00:57<00:00, 111.38it/s]
# Processing door_stop: 100%|██████████| 2823/2823 [00:25<00:00, 109.02it/s]
# MFCC Features Shape: (12724, 13, 51)
# Model Input Shape: (13, 51)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_1 (Reshape)         (None, 13, 51, 1)         0
#
#  conv2d_2 (Conv2D)           (None, 11, 49, 8)         80
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 24, 8)          0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 5, 24, 8)          0
#
#  conv2d_3 (Conv2D)           (None, 3, 22, 16)         1168
#
#  max_pooling2d_3 (MaxPoolin  (None, 1, 11, 16)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 1, 11, 16)         0
#
#  flatten_1 (Flatten)         (None, 176)               0
#
#  dense_1 (Dense)             (None, 3)                 531
#
# =================================================================
# Total params: 1779 (6.95 KB)
# Trainable params: 1779 (6.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 319/319 [==============================] - 4s 11ms/step - loss: 0.6194 - accuracy: 0.7424 - val_loss: 0.4196 - val_accuracy: 0.8566
# Epoch 2/100
# 319/319 [==============================] - 3s 11ms/step - loss: 0.4410 - accuracy: 0.8370 - val_loss: 0.3478 - val_accuracy: 0.8931
# Epoch 3/100
# 319/319 [==============================] - 5s 17ms/step - loss: 0.3910 - accuracy: 0.8578 - val_loss: 0.3010 - val_accuracy: 0.8912
# Epoch 4/100
# 319/319 [==============================] - 3s 11ms/step - loss: 0.3550 - accuracy: 0.8724 - val_loss: 0.2412 - val_accuracy: 0.9273
# Epoch 5/100
# 319/319 [==============================] - 3s 10ms/step - loss: 0.3321 - accuracy: 0.8793 - val_loss: 0.2811 - val_accuracy: 0.9277
# Epoch 6/100
# 319/319 [==============================] - 3s 10ms/step - loss: 0.3263 - accuracy: 0.8845 - val_loss: 0.2369 - val_accuracy: 0.9289
# Epoch 7/100
# 319/319 [==============================] - 5s 16ms/step - loss: 0.3191 - accuracy: 0.8875 - val_loss: 0.2184 - val_accuracy: 0.9297
# Epoch 8/100
# 319/319 [==============================] - 4s 12ms/step - loss: 0.3189 - accuracy: 0.8862 - val_loss: 0.2368 - val_accuracy: 0.9289
# Epoch 9/100
# 319/319 [==============================] - 3s 10ms/step - loss: 0.3121 - accuracy: 0.8886 - val_loss: 0.2339 - val_accuracy: 0.9234
# Epoch 10/100
# 319/319 [==============================] - 3s 10ms/step - loss: 0.3042 - accuracy: 0.8923 - val_loss: 0.1979 - val_accuracy: 0.9403
# Epoch 11/100
# 319/319 [==============================] - 5s 16ms/step - loss: 0.2877 - accuracy: 0.8964 - val_loss: 0.2085 - val_accuracy: 0.9379
# Epoch 12/100
# 319/319 [==============================] - 4s 12ms/step - loss: 0.2831 - accuracy: 0.8981 - val_loss: 0.2205 - val_accuracy: 0.9391
# Epoch 13/100
# 319/319 [==============================] - 4s 12ms/step - loss: 0.2955 - accuracy: 0.8913 - val_loss: 0.2153 - val_accuracy: 0.9434
# Epoch 14/100
# 319/319 [==============================] - 3s 10ms/step - loss: 0.2862 - accuracy: 0.8995 - val_loss: 0.1889 - val_accuracy: 0.9399
# Epoch 15/100
# 319/319 [==============================] - 7s 23ms/step - loss: 0.2844 - accuracy: 0.8987 - val_loss: 0.2344 - val_accuracy: 0.9301
# Epoch 16/100
# 319/319 [==============================] - 5s 17ms/step - loss: 0.2727 - accuracy: 0.9061 - val_loss: 0.1922 - val_accuracy: 0.9462
# Epoch 17/100
# 319/319 [==============================] - 5s 15ms/step - loss: 0.2757 - accuracy: 0.9043 - val_loss: 0.1971 - val_accuracy: 0.9371
# Epoch 18/100
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2783 - accuracy: 0.8994 - val_loss: 0.1969 - val_accuracy: 0.9379
# Epoch 19/100
# 319/319 [==============================] - 5s 17ms/step - loss: 0.2646 - accuracy: 0.9050 - val_loss: 0.1874 - val_accuracy: 0.9450
# Epoch 20/100
# 319/319 [==============================] - 3s 10ms/step - loss: 0.
100
# 319/319 [==============================] - 3s 10ms/step - loss: 0.2180 - accuracy: 0.9250 - val_loss: 0.1627 - val_accuracy: 0.9532
# Epoch 91/100
# 319/319 [==============================] - 4s 12ms/step - loss: 0.2371 - accuracy: 0.9177 - val_loss: 0.1426 - val_accuracy: 0.9509
# Epoch 92/100
# 319/319 [==============================] - 5s 17ms/step - loss: 0.2376 - accuracy: 0.9154 - val_loss: 0.1723 - val_accuracy: 0.9505
# Epoch 93/100
# 319/319 [==============================] - 3s 11ms/step - loss: 0.2303 - accuracy: 0.9209 - val_loss: 0.1460 - val_accuracy: 0.9548
# Epoch 94/100
# 319/319 [==============================] - 3s 11ms/step - loss: 0.2235 - accuracy: 0.9209 - val_loss: 0.1614 - val_accuracy: 0.9454
# Epoch 95/100
# 319/319 [==============================] - 4s 12ms/step - loss: 0.2359 - accuracy: 0.9174 - val_loss: 0.1453 - val_accuracy: 0.9599
# Epoch 96/100
# 319/319 [==============================] - 5s 17ms/step - loss: 0.2311 - accuracy: 0.9219 - val_loss: 0.1549 - val_accuracy: 0.9434
# Epoch 97/100
# 319/319 [==============================] - 3s 10ms/step - loss: 0.2317 - accuracy: 0.9191 - val_loss: 0.1588 - val_accuracy: 0.9560
# Epoch 98/100
# 319/319 [==============================] - 4s 11ms/step - loss: 0.2292 - accuracy: 0.9160 - val_loss: 0.1474 - val_accuracy: 0.9560
# Epoch 99/100
# 319/319 [==============================] - 3s 11ms/step - loss: 0.2406 - accuracy: 0.9170 - val_loss: 0.1391 - val_accuracy: 0.9568
# Epoch 100/100
# 319/319 [==============================] - 5s 17ms/step - loss: 0.2258 - accuracy: 0.9232 - val_loss: 0.1251 - val_accuracy: 0.9572

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Function to calculate and print multiple evaluation metrics
def evaluate_model(model, X_test, y_test, label_encoder):
    # Predictions on test set
    y_pred = model.predict(X_test)
    
    # Convert predictions to class labels
    y_pred_labels = label_encoder.inverse_transform(np.argmax(y_pred, axis=1))

    # Calculate and print accuracy
    accuracy = accuracy_score(y_test, y_pred_labels)
    print(f'Accuracy: {accuracy * 100:.2f}%')

    # Calculate and print precision, recall, and F1 score
    precision = precision_score(y_test, y_pred_labels, average='weighted')
    recall = recall_score(y_test, y_pred_labels, average='weighted')
    f1 = f1_score(y_test, y_pred_labels, average='weighted')

    print(f'Precision: {precision * 100:.2f}%')
    print(f'Recall: {recall * 100:.2f}%')
    print(f'F1 Score: {f1 * 100:.2f}%')

    # Generate and plot confusion matrix
    cm = confusion_matrix(y_test, y_pred_labels, labels=label_encoder.classes_)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming you have the trained_model, X_test, y_test, and label_encoder
evaluate_model(trained_model, X_test, y_test, label_encoder)
# Out:
# 80/80 [==============================] - 0s 4ms/step
# Accuracy: 95.72%
# Precision: 95.81%
# Recall: 95.72%
# F1 Score: 95.73%

# %%
import matplotlib.pyplot as plt
import numpy as np
import librosa.display

# Load audio file
audio_file = 'Backend/TestAudio1.wav'
audio, sr = librosa.load(audio_file, sr=None)  # Load with original sampling rate

# Create a time array for x-axis
time = np.arange(0, len(audio)) / sr

# Plotting
plt.figure(figsize=(10, 4))
librosa.display.waveshow(audio, sr=sr, alpha=0.8)
plt.xlabel('Time (s)')
plt.ylabel('Frequency')
plt.title('Waveform of Audio')
plt.colorbar(format='%+2.0f dB')
plt.show()
